# %%
# !pip -q install rdkit==2024.3.4
# !pip -q install scikit-fingerprints
# !pip -q install kora py3Dmol
# !pip -q install kaleido==0.2.1
# !pip -q install jupyter-dash
# !pip -q install molplotly --no-deps
# !pip -q install molvs
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.3/468.3 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 54.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 61.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 3.0 MB/s eta 0:00:00
# ...

# %%
# Clonar el repositorio de GitHub
# !git clone https://github.com/IsrC11/MAYA.git
# Out:
# Cloning into 'MAYA'...
# remote: Enumerating objects: 1492, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 1492 (delta 111), reused 52 (delta 52), pack-reused 1361 (from 5)
# Receiving objects: 100% (1492/1492), 15.87 MiB | 12.90 MiB/s, done.
# Resolving deltas: 100% (931/931), done.

# %%
# %cd MAYA/
# Out:
# /content/MAYA

# %%
# !pip install -e . -q
# Out:
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.9 MB/s eta 0:00:00
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ERROR: Could not find a version that satisfies the requirement rdkit-pypi>=2021.9.4 (from molplotly) (from versions: none)
# ERROR: No matching distribution found for rdkit-pypi>=2021.9.4

# %%
from maya_chem import *

# %%
from maya_chem import MayaAnalyzer, MayaConfig
import numpy as np

# Crear configuración
config = MayaConfig(data_path="/content/Dataset_Fungi_Chembl.xlsx")

# Actualizar claves relevantes
config.data.update({
    "id_col": "molregno",
    "smiles_col": "canonical_smiles",
    "activities": ["standard_value"]
})
config.analysis["fingerprint"] = ["morgan", 'maccs'] #'map4'
config.analysis["reduction_method"] = ['pca'] #'tsne' 'umap'
config.viz["output_dir"] = "/content/MAYA/colab_results"

# Correr pipeline
analyzer = MayaAnalyzer(config)
results = analyzer.run(color_by='standard_value')
figs = analyzer.visualize(interactive_mode=True, color_by='standard_value')

print("✅ Pipeline completed. Check '/content/MAYA/colab_results' for outputs.")

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/Dataset_Fungi_Chembl.xlsx')

# %%
print(df.columns)
# Out:
# Index(['molregno', 'standard_inchi_key', 'canonical_smiles', 'full_molformula',
#        'full_mwt', 'full_mwt.1', 'mw_monoisotopic', 'compound_name',
#        'standard_type', 'standard_value', 'standard_units', 'assay_type', 'l1',
#        'l2', 'l3', 'organism', 'pref_name', 'chembl_id', 'doc_id', 'doi'],
#       dtype='object')
